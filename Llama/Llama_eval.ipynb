# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# !pip install -U tokenizers;
# !pip install -U transformers;
# !pip install -U peft;
# !pip install -U bitsandbytes;
# !pip install huggingface_hub ipython "unsloth[colab] @ git+https://github.com/unslothai/unsloth.git";
# Out:
# Requirement already satisfied: tokenizers in /opt/conda/lib/python3.9/site-packages (0.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/conda/lib/python3.9/site-packages (from tokenizers) (0.24.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (2024.7.4)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.9/site-packages (4.43.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.9/site-packages (from transformers) (0.24.5)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.9/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.9/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.9/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.9/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: peft in /opt/conda/lib/python3.9/site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.9/site-packages (from peft) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from peft) (23.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.9/site-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.9/site-packages (from peft) (6.0)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.9/site-packages (from peft) (2.1.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.9/site-packages (from peft) (4.43.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from peft) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/conda/lib/python3.9/site-packages (from peft) (0.33.0)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.9/site-packages (from peft) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /opt/conda/lib/python3.9/site-packages (from peft) (0.24.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (2024.5.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (1.11.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.5.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.5.82)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.9/site-packages (from transformers->peft) (2024.7.24)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.9/site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.2)
# Requirement already satisfied: decorator<5,>=4.3 in /opt/conda/lib/python3.9/site-packages (from networkx->torch>=1.13.0->peft) (4.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.9/site-packages (0.43.3)
# Requirement already satisfied: torch in /opt/conda/lib/python3.9/site-packages (from bitsandbytes) (2.1.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from bitsandbytes) (1.23.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (3.9.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (1.11.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (2.5.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch->bitsandbytes) (2.1.2)
# Requirement already satisfied: decorator<5,>=4.3 in /opt/conda/lib/python3.9/site-packages (from networkx->torch->bitsandbytes) (4.4.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-44pqmfmn/unsloth_c906e5f9ec654738944a09ffa1568850
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-44pqmfmn/unsloth_c906e5f9ec654738944a09ffa1568850
#   Resolved https://github.com/unslothai/unsloth.git to commit 4e570be9ae4ced8cdc64e498125708e34942befc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.9/site-packages (0.24.5)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.9/site-packages (8.12.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from huggingface_hub) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from ipython) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from ipython) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.9/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.9/site-packages (from ipython) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.9/site-packages (from ipython) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.9/site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.9/site-packages (from ipython) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.9/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface_hub) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface_hub) (2024.7.4)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.9/site-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.9/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.43.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.9/site-packages (from bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.23.5)
# Collecting xformers@ https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp39-cp39-manylinux2014_x86_64.whl (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git)
#   Using cached https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp39-cp39-manylinux2014_x86_64.whl (211.8 MB)
# Requirement already satisfied: tyro in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.8.5)
# Requirement already satisfied: transformers>=4.43.2 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.43.3)
# Requirement already satisfied: datasets>=2.16.0 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.20.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.43.0)
# Requirement already satisfied: accelerate>=0.26.1 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.33.0)
# Requirement already satisfied: trl<0.9.0,>=0.7.9 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.8.6)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.12.0)
# Requirement already satisfied: protobuf<4.0.0 in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: hf-transfer in /opt/conda/lib/python3.9/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.1.8)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.9/site-packages (from accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.4.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.9/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.9/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.0.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.9/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.9/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.70.15)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.9/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.8.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.11.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.5.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.9/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (12.5.82)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.9/site-packages (from transformers>=4.43.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2024.7.24)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.9/site-packages (from transformers>=4.43.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.19.1)
# Requirement already satisfied: docstring-parser>=0.16 in /opt/conda/lib/python3.9/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.9/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (13.3.5)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.9/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: eval-type-backport>=0.1.3 in /opt/conda/lib/python3.9/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.9/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.9/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.9/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/conda/lib/python3.9/site-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)

# %%
import pandas as pd

def determine_preference(row):
    if row['winner_model_a'] == 1:
        return 0
    elif row['winner_model_b'] == 1:
        return 1 
    elif row['winner_tie'] == 1:
        return 2

training_data = pd.read_csv('./Data/train.csv')
training_data['preference'] = training_data.apply(determine_preference, axis=1)

# %%
import torch
from unsloth import FastLanguageModel
from transformers import AutoTokenizer, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score, log_loss, classification_report
from peft import PeftModel

class ModelEvaluator:
    def __init__(self, config, num_labels=3):
        self.config = config

        # Load the base model and tokenizer
        self.model, self.tokenizer = FastLanguageModel.from_pretrained(
            model_name=config['checkpoint'],
            dtype=torch.float16,
            load_in_4bit=True,
            device_map="auto"
        )

        self.model.config.max_position_embeddings = 2048 

        # Modify the output layer
        self.model.lm_head = torch.nn.Linear(in_features=self.model.lm_head.in_features, out_features=num_labels, bias=False)

        # Load PEFT model
        self.model = PeftModel.from_pretrained(self.model, config['peft_model_path'])

        # Move the model to CUDA
        self.model = self.model.to('cuda')

        self.training_args = TrainingArguments(
            output_dir=self.config["output_dir"],
            per_device_eval_batch_size=self.config["per_device_eval_batch_size"],
            logging_dir='./logs',
            fp16=True,  
        )

        self.trainer = Trainer(
            model=self.model,
            args=self.training_args,
            tokenizer=self.tokenizer,
            compute_metrics=self.compute_metrics,
        )

    def generate_prompt(self, data_point):
        return f"""Analyze the conversation between two chatbots (model_a and model_b) and their corresponding responses (response_a and response_b) to a given prompt. Determine which model provided the more preferred response based on the human preference label (Preference). Return the predicted preference as one of three labels: 'winner_model_a', 'winner_model_b', or 'winner_tie', along with the logits for each label.

        Prompt: {data_point['prompt']}
        Model A Response: {data_point['response_a']}
        Model B Response: {data_point['response_b']}
        """

    def compute_metrics(self, eval_preds):
        preds = eval_preds.predictions.argmax(-1)
        labels = eval_preds.label_ids
        probs = torch.from_numpy(eval_preds.predictions).float().softmax(-1).numpy()

        loss = log_loss(y_true=labels, y_pred=probs)
        acc = accuracy_score(y_true=labels, y_pred=preds)
        return {"acc": acc, "log_loss": loss}

    def evaluate_model(self, dataset, description="Evaluation"):
        def preprocess_and_generate_prompt(batch):
            processed_prompts = []
            for row in batch:
                generated_prompt = self.generate_prompt(row)
                processed_prompts.append(generated_prompt)

            batch['prompt'] = processed_prompts
            tokenized = self.tokenizer(
                batch['prompt'], 
                padding=True, 
                truncation=True, 
                max_length=self.model.config.max_position_embeddings, 
                return_tensors='pt'
            ).to('cuda')
            return {**tokenized, 'labels': batch['labels'].to('cuda')}

        dataset = dataset.map(preprocess_and_generate_prompt, batched=True)

        eval_results = self.trainer.evaluate(eval_dataset=dataset)
        print(f"{description} results:", eval_results)
        return eval_results

    def predict_preference(self, data_point):
        generated_prompt = self.generate_prompt(data_point)
        inputs = self.tokenizer(
            generated_prompt, 
            return_tensors="pt", 
            truncation=True, 
            max_length=self.model.config.max_position_embeddings  # Truncate to the model's max length
        ).to('cuda')
        
        with torch.no_grad():
            model_output = self.model(**inputs)
            logits = model_output.logits
        
        preference_logits = logits[:, -1, :]

        preference = torch.argmax(preference_logits, dim=-1).item()
        return preference

    def evaluate_on_sample(self, sample_data):
        actual_preferences = []
        predicted_preferences = []

        for _, row in sample_data.iterrows():
            actual_preference = row['preference']
            actual_preferences.append(actual_preference)

            predicted_preference = self.predict_preference(row)
            predicted_preferences.append(predicted_preference)

        accuracy = accuracy_score(actual_preferences, predicted_preferences)
        print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2024-08-03 10:24:12.099982: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-03 10:24:12.962028: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
config = {
    "checkpoint": "./Llama",
    "output_dir": "./Llama/results",
    "per_device_eval_batch_size": 4,
    "peft_model_path": "./Llama/Llama_prompt" 
}

# %%
shuffled_data = training_data.sample(frac=1, random_state=42).reset_index(drop=True)
sample_data = shuffled_data.head(50)

# %%
model_evaluator = ModelEvaluator(config)
model_evaluator.evaluate_on_sample(sample_data)
# Out:
# ==((====))==  Unsloth 2024.8: Fast Llama patching. Transformers = 4.43.3.
#    \\   /|    GPU: NVIDIA A16. Max memory: 14.542 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.1.0+cu121. CUDA = 8.6. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.22.post7. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Accuracy: 36.00%
